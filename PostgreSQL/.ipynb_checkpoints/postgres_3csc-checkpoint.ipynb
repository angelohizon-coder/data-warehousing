# %%
# Psycopg2 is the most popular PostgreSQL database adapter
# database connector connects the database to any application and the implementation is held through a database adapter
import psycopg2 as pc

# numpy is a package of python that provides extra feature to list
import numpy as np
import pandas as pd
import csv as reader

# %%
conn = pc.connect("dbname = dw_3csc user = postgres password = @Ngelo8998 host = localhost")
conn
c = conn.cursor()

# %%
c.execute("INSERT INTO students_3csc VALUES(2019130134, 'John Angelo', 'Algarne', 20, 4.20, 'M')")

# %%
c.execute("SELECT * FROM public.students_3csc")

# %%
c.fetchall()
# Out:
# [(2019130134, 'John Angelo', 'Algarne', 20, 4.2, 'M')]

# %%
id = input('ID: ')
firstname = input('First Name: ')
familyname = input('Family Name: ')
age = input('Age: ')
gwa = input('GWA: ')
gender = input('Gender: ')
# Out:
# ID: 2019132083
# First Name: Angelo Louis
# Family Name: Hizon
# Age: 20
# GWA: 5.00
# Gender: M

# %%
c.execute("INSERT INTO students_3csc VALUES(%s, %s, %s, %s, %s, %s)", (id, firstname, familyname, age, gwa, gender))

# %%
c.execute("SELECT * FROM public.students_3csc")

# %%
c.fetchall()
# Out:
# [(2019130134, 'John Angelo', 'Algarne', 20, 4.2, 'M'),
#  (2019132083, 'Angelo Louis', 'Hizon', 20, 5.0, 'M')]

# %%
set_of_students = [(2019129789,'Chlarizza', 'Torres', 21, 5.00, 'F'),
                   (2019132627, 'Abraham', 'Militar', 20, 2.00, 'M'),
                   (2019128089, 'Andrei', 'Benitez',20 ,4.20, 'M')]

# %%
c.executemany("INSERT INTO students_3csc VALUES(%s, %s, %s, %s, %s, %s)", set_of_students)

# %%
c.execute("SELECT * FROM public.students_3csc")

# %%
c.fetchall()
# Out:
# [(2019130134, 'John Angelo', 'Algarne', 20, 4.2, 'M'),
#  (2019132083, 'Angelo Louis', 'Hizon', 20, 5.0, 'M'),
#  (2019129789, 'Chlarizza', 'Torres', 21, 5.0, 'F'),
#  (2019132627, 'Abraham', 'Militar', 20, 2.0, 'M'),
#  (2019128089, 'Andrei', 'Benitez', 20, 4.2, 'M')]

# %%
csc_g1 = pd.read_csv('3csc - csc_info2.csv')

# %%
csc_g2 = pd.read_csv('3csc - csc_info1.csv')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:@Ngelo8998@localhost:5432/dw_3csc')

# %%
csc_g2.to_sql('students_3csc', engine, index = False, if_exists = 'replace')

# %%
completeOne = pd.read_sql_query("SELECT * FROM students_3csc", conn)
completeOne
# Out:
#             id         firstname familyname  age   gwa gender
# 0   2018107987       John Louise     Lagazo   21  1.69      M
# 1   2019130134       John Angelo    Algarne   20  4.20      M
# 2   2019132083            Angelo      Hizon   20  5.00      M
# 3   2019129789         Chlarizza     Torres   21  5.00      F
# 4   2019132627          Abraham     Militar   20  2.00      M
# 5   2019128089            Andrei    Benitez   20  4.20      M
# 6   2019131905             Keane     Tejada   20  1.00      M
# 7   2019128151             Anton     Bondoc   20  5.00      M
# 8   2018117965       Carl Joseph       Paez   21  2.00      M
# 9   2019128312              Karl  Tabajonda   21  1.00      M
# 10  2019128272             Carlo   Sindayen   20  2.00      M
# 11  2019128232             Aaron     Santos   21  3.14      M
# 12  2015081794             Allen    Marders   22  5.00      M
# 13  2019128253           Bridget      Plaza   20  2.00      F
# 14  2019127901            Enrico      Oliva   20  3.00      M
# 15  2019128145       Jasmine Joy        Lam   20  1.00      F
# 16  2019128203             Ronan   Doncillo   21  3.00      M
# 17  2019128149             Rowel    Buluran   19  5.00      M
# 18  2019128005          Dominick    Segundo   20  5.00      M
# 19  2019128314             Franz       Amog   21  3.00      M
# 20  2019127972  Kerwin Dominique     Aquino   20  1.00      M
# 21  2019128026  Lorenz Christian      Tadeo   21  3.00      M
# 22  2019131291       Leira Marie    Teodoro   20  2.00      F
# 23  2019131907       Lester John   Quilaman   20  1.01      M
# 24  2019128213          John Vic       Ilas   21  2.00      M

# %%
csc_g1.to_sql('students_3csc_grades', engine, index = False, if_exists = 'replace')

# %%
completeTwo = pd.read_sql_query("SELECT * FROM students_3csc_grades", conn)
completeTwo
# Out:
#     applicant_no  ustet_score  jhs_gwa  shs_gwa strand familyname
# 0     2018107987        80.00    91.00    94.00    ABM     Lagazo
# 1     2019130134        69.00    88.88    77.77   STEM    Algarne
# 2     2019132083        87.00    91.42    93.00   STEM      Hizon
# 3     2019129789        95.00    96.00    97.00    GAS     Torres
# 4     2019132627        88.00    90.00    91.00   STEM    Militar
# 5     2019128089        69.42    80.08    96.69   STEM    Benitez
# 6     2019131905        90.00    90.00    90.00   STEM     Tejada
# 7     2019128151        97.00    94.17    93.24    ABM     Bondoc
# 8     2018117965        88.00    89.68    91.36    ABM       Paez
# 9     2019128312        90.00    91.00    92.00    ABM  Tabajonda
# 10    2019128272        85.00    86.00    92.00   PEST   Sindayen
# 11    2019128232        92.00    87.50    88.90   STEM     Santos
# 12    2015081794        85.00    90.00    95.00  HUMMS    Marders
# 13    2019128253        91.00    91.00    91.00   STEM      Plaza
# 14    2019127901        85.00    92.00    89.00   STEM      Oliva
# 15    2019128145        90.00    91.00    94.00   STEM        Lam
# 16    2019128203        96.00    84.00    90.00   STEM   Doncillo
# 17    2019128149        76.00    75.00    75.00   STEM    Buluran
# 18    2019128005        75.00    76.00    77.00   STEM    Segundo
# 19    2019128314        89.00    90.00    90.00   STEM       Amog
# 20    2019127972        90.00    87.00    85.00   STEM     Aquino
# 21    2019128026        85.00    85.00    85.00    ICT      Tadeo
# 22    2019131291        89.50    90.00    87.00    ABM    Teodoro
# 23    2019128213        86.00    84.00    91.00   STEM       Ilas
# 24    2019131907        79.00    89.00    99.00    MAD   Quilaman

# %%
complete = pd.read_sql_query("SELECT id, firstname, students_3csc.familyname, age, gwa, ustet_score, jhs_gwa, shs_gwa, strand FROM students_3csc INNER JOIN students_3csc_grades ON students_3csc.id = students_3csc_grades.applicant_no", conn)
complete
# Out:
#             id         firstname familyname  age   gwa  ustet_score  jhs_gwa  \
# 0   2018107987       John Louise     Lagazo   21  1.69        80.00    91.00
# 1   2019130134       John Angelo    Algarne   20  4.20        69.00    88.88
# 2   2019132083            Angelo      Hizon   20  5.00        87.00    91.42
# 3   2019129789         Chlarizza     Torres   21  5.00        95.00    96.00
# 4   2019132627          Abraham     Militar   20  2.00        88.00    90.00
# 5   2019128089            Andrei    Benitez   20  4.20        69.42    80.08
# 6   2019131905             Keane     Tejada   20  1.00        90.00    90.00
# 7   2019128151             Anton     Bondoc   20  5.00        97.00    94.17
# 8   2018117965       Carl Joseph       Paez   21  2.00        88.00    89.68
# 9   2019128312              Karl  Tabajonda   21  1.00        90.00    91.00
# 10  2019128272             Carlo   Sindayen   20  2.00        85.00    86.00
# 11  2019128232             Aaron     Santos   21  3.14        92.00    87.50
# 12  2015081794             Allen    Marders   22  5.00        85.00    90.00
# 13  2019128253           Bridget      Plaza   20  2.00        91.00    91.00
# 14  2019127901            Enrico      Oliva   20  3.00        85.00    92.00
# 15  2019128145       Jasmine Joy        Lam   20  1.00        90.00    91.00
# 16  2019128203             Ronan   Doncillo   21  3.00        96.00    84.00
# 17  2019128149             Rowel    Buluran   19  5.00        76.00    75.00
# 18  2019128005          Dominick    Segundo   20  5.00        75.00    76.00
# 19  2019128314             Franz       Amog   21  3.00        89.00    90.00
# 20  2019127972  Kerwin Dominique     Aquino   20  1.00        90.00    87.00
# 21  2019128026  Lorenz Christian      Tadeo   21  3.00        85.00    85.00
# 22  2019131291       Leira Marie    Teodoro   20  2.00        89.50    90.00
# 23  2019128213          John Vic       Ilas   21  2.00        86.00    84.00
# 24  2019131907       Lester John   Quilaman   20  1.01        79.00    89.00
#
#     shs_gwa strand
# 0     94.00    ABM
# 1     77.77   STEM
# 2     93.00   STEM
# 3     97.00    GAS
# 4     91.00   STEM
# 5     96.69   STEM
# 6     90.00   STEM
# 7     93.24    ABM
# 8     91.36    ABM
# 9     92.00    ABM
# 10    92.00   PEST
# 11    88.90   STEM
# 12    95.00  HUMMS
# 13    91.00   STEM
# 14    89.00   STEM
# 15    94.00   STEM
# 16    90.00   STEM
# 17    75.00   STEM
# 18    77.00   STEM
# 19    90.00   STEM
# 20    85.00   STEM
# 21    85.00    ICT
# 22    87.00    ABM
# 23    91.00   STEM
# 24    99.00    MAD

# %%
complete.to_csv('grades.csv', index=False)

# %%
csc = open ('3csc - csc_info1.csv')
csc_a = csv.reader(csc)

# %%
c.execute('SELECT * FROM students_3csc')

# %%
c.fetchall()
# Out:
# [(2018107987, 'John Louise', 'Lagazo', 21, 1.69, 'M'),
#  (2019130134, 'John Angelo', 'Algarne', 20, 4.2, 'M'),
#  (2019132083, 'Angelo', 'Hizon', 20, 5.0, 'M'),
#  (2019129789, 'Chlarizza', 'Torres', 21, 5.0, 'F'),
#  (2019132627, 'Abraham ', 'Militar', 20, 2.0, 'M'),
#  (2019128089, 'Andrei', 'Benitez', 20, 4.2, 'M'),
#  (2019131905, 'Keane', 'Tejada', 20, 1.0, 'M'),
#  (2019128151, 'Anton', 'Bondoc', 20, 5.0, 'M'),
#  (2018117965, 'Carl Joseph', 'Paez', 21, 2.0, 'M'),
#  (2019128312, 'Karl', 'Tabajonda', 21, 1.0, 'M'),
#  (2019128272, 'Carlo', 'Sindayen', 20, 2.0, 'M'),
#  (2019128232, 'Aaron', 'Santos', 21, 3.14, 'M'),
#  (2015081794, 'Allen', 'Marders', 22, 5.0, 'M'),
#  (2019128253, 'Bridget', 'Plaza', 20, 2.0, 'F'),
#  (2019127901, 'Enrico', 'Oliva', 20, 3.0, 'M'),
#  (2019128145, 'Jasmine Joy', 'Lam', 20, 1.0, 'F'),
#  (2019128203, 'Ronan', 'Doncillo', 21, 3.0, 'M'),
#  (2019128149, 'Rowel', 'Buluran', 19, 5.0, 'M'),
#  (2019128005, 'Dominick', 'Segundo', 20, 5.0, 'M'),
#  (2019128314, 'Franz', 'Amog', 21, 3.0, 'M'),
#  (2019127972, 'Kerwin Dominique', 'Aquino', 20, 1.0, 'M'),
#  (2019128026, 'Lorenz Christian', 'Tadeo', 21, 3.0, 'M'),
#  (2019131291, 'Leira Marie', 'Teodoro', 20, 2.0, 'F'),
#  (2019131907, 'Lester John', 'Quilaman', 20, 1.01, 'M'),
#  (2019128213, 'John Vic', 'Ilas', 21, 2.0, 'M')]

# %%
c.execute('SELECT * FROM students_3csc_grades')

# %%
c.fetchall()
# Out:
# [(2018107987, 80.0, 91.0, 94.0, 'ABM', 'Lagazo'),
#  (2019130134, 69.0, 88.88, 77.77, 'STEM', 'Algarne'),
#  (2019132083, 87.0, 91.42, 93.0, 'STEM', 'Hizon'),
#  (2019129789, 95.0, 96.0, 97.0, 'GAS', 'Torres'),
#  (2019132627, 88.0, 90.0, 91.0, 'STEM', 'Militar'),
#  (2019128089, 69.42, 80.08, 96.69, 'STEM', 'Benitez'),
#  (2019131905, 90.0, 90.0, 90.0, 'STEM', 'Tejada'),
#  (2019128151, 97.0, 94.17, 93.24, 'ABM', 'Bondoc'),
#  (2018117965, 88.0, 89.68, 91.36, 'ABM', 'Paez'),
#  (2019128312, 90.0, 91.0, 92.0, 'ABM', 'Tabajonda'),
#  (2019128272, 85.0, 86.0, 92.0, 'PEST', 'Sindayen'),
#  (2019128232, 92.0, 87.5, 88.9, 'STEM', 'Santos'),
#  (2015081794, 85.0, 90.0, 95.0, 'HUMMS', 'Marders'),
#  (2019128253, 91.0, 91.0, 91.0, 'STEM', 'Plaza'),
#  (2019127901, 85.0, 92.0, 89.0, 'STEM', 'Oliva'),
#  (2019128145, 90.0, 91.0, 94.0, 'STEM', 'Lam'),
#  (2019128203, 96.0, 84.0, 90.0, 'STEM', 'Doncillo'),
#  (2019128149, 76.0, 75.0, 75.0, 'STEM', 'Buluran'),
#  (2019128005, 75.0, 76.0, 77.0, 'STEM', 'Segundo'),
#  (2019128314, 89.0, 90.0, 90.0, 'STEM', 'Amog'),
#  (2019127972, 90.0, 87.0, 85.0, 'STEM', 'Aquino'),
#  (2019128026, 85.0, 85.0, 85.0, 'ICT', 'Tadeo'),
#  (2019131291, 89.5, 90.0, 87.0, 'ABM', 'Teodoro'),
#  (2019131907, 79.0, 89.0, 99.0, 'MAD', 'Quilaman'),
#  (2019128213, 86.0, 84.0, 91.0, 'STEM', 'Ilas')]

# %%
csc = open('3csc - csc_info2 - without header.csv')
csc_csv = csv.reader(csc)

# %%
c.executemany("INSERT INTO students_3csc_grades VALUES(%s, %s, %s, %s, %s)", csc_csv)

# %%
conn.commit()

# %%
c.execute("""
    SELECT id, familyname FROM students_3csc 
    LEFT JOIN students_3csc_grades 
    ON students_3csc.id = students_3csc_grades.applicant_no
    WHERE shs_gwa > 91
""")
c.fetchall()
# Out:
# [(2018107987, 'Lagazo'),
#  (2019132083, 'Hizon'),
#  (2019129789, 'Torres'),
#  (2019128089, 'Benitez'),
#  (2019128151, 'Bondoc'),
#  (2018117965, 'Paez'),
#  (2019128312, 'Tabajonda'),
#  (2019128272, 'Sindayen'),
#  (2015081794, 'Marders'),
#  (2019128145, 'Lam'),
#  (2019131907, 'Quilaman')]

# %%
c.execute("""
    SELECT id, familyname FROM students_3csc 
    RIGHT JOIN students_3csc_grades 
    ON students_3csc.id = students_3csc_grades.applicant_no
    WHERE shs_gwa > 91
""")
c.fetchall()
# Out:
# [(2018107987, 'Lagazo'),
#  (2019132083, 'Hizon'),
#  (2019129789, 'Torres'),
#  (2019128089, 'Benitez'),
#  (2019128151, 'Bondoc'),
#  (2018117965, 'Paez'),
#  (2019128312, 'Tabajonda'),
#  (2019128272, 'Sindayen'),
#  (2015081794, 'Marders'),
#  (2019128145, 'Lam'),
#  (2019131907, 'Quilaman')]

# %%
query = ('''
SELECT 
    id,
    familyname,
    gender,
    age,
    gwa, jhs_gwa, shs_gwa, strand
FROM
    students_3csc
        INNER JOIN 
    students_3csc_grades
        ON
    students_3csc.id = students_3csc_grades.applicant_no
''')
c.execute(query)
c.fetchmany(5)
# Out:
# [(2018107987, 'Lagazo', 'M', 21, 1.69, 91.0, 94.0, 'ABM'),
#  (2019130134, 'Algarne', 'M', 20, 4.2, 88.88, 77.77, 'STEM'),
#  (2019132083, 'Hizon', 'M', 20, 5.0, 91.42, 93.0, 'STEM'),
#  (2019129789, 'Torres', 'F', 21, 5.0, 96.0, 97.0, 'GAS'),
#  (2019132627, 'Militar', 'M', 20, 2.0, 90.0, 91.0, 'STEM')]

# %%
query = ('''
SELECT 
    id, familyname, age, gender
    FROM students_3csc FULL JOIN students_3csc_grades
    ON students_3csc.id = students_3csc_grades.applicant_no
    WHERE age < 22 AND gender ='M'
''')
c.execute(query)
c.fetchmany(5)
# Out:
# [(2018107987, 'Lagazo', 21, 'M'),
#  (2019130134, 'Algarne', 20, 'M'),
#  (2019132083, 'Hizon', 20, 'M'),
#  (2019132627, 'Militar', 20, 'M'),
#  (2019128089, 'Benitez', 20, 'M')]

# %%
query5 = ("""
    SELECT id, familyname, applicant_no 
    FROM students_3csc_grades 
    NATURAL JOIN students_3csc
    WHERE gwa BETWEEN 1 AND 2
""")
c.execute(query5)

# %%
c.fetchall()
# Out:
# [(2018107987, 'Lagazo', 2018107987),
#  (2018107987, 'Lagazo', 2019130134),
#  (2018107987, 'Lagazo', 2019132083),
#  (2018107987, 'Lagazo', 2019129789),
#  (2018107987, 'Lagazo', 2019132627),
#  (2018107987, 'Lagazo', 2019128089),
#  (2018117965, 'Paez', 2019130134),
#  (2018117965, 'Paez', 2019132083),
#  (2018117965, 'Paez', 2019129789),
#  (2018117965, 'Paez', 2019132627),
#  (2018117965, 'Paez', 2019128089),
#  (2018117965, 'Paez', 2019131905),
#  (2018117965, 'Paez', 2019128151),
#  (2018117965, 'Paez', 2018117965),
#  (2018117965, 'Paez', 2019128312),
#  (2018117965, 'Paez', 2019128272),
#  (2018117965, 'Paez', 2019128232),
#  (2018117965, 'Paez', 2015081794),
#  (2018117965, 'Paez', 2019128253),
#  (2018117965, 'Paez', 2019127901),
#  (2018117965, 'Paez', 2019128145),
#  (2018117965, 'Paez', 2019128203),
#  (2018117965, 'Paez', 2019128149),
#  (2018117965, 'Paez', 2019128005),
#  (2018117965, 'Paez', 2019128314),
#  (2018117965, 'Paez', 2019127972),
#  (2018117965, 'Paez', 2019128026),
#  (2018117965, 'Paez', 2019131291),
#  (2018117965, 'Paez', 2019131907),
#  (2018117965, 'Paez', 2019128213),
#  (2019128312, 'Tabajonda', 2018107987),
#  (2019128312, 'Tabajonda', 2019130134),
#  (2019128312, 'Tabajonda', 2019132083),
#  (2019128312, 'Tabajonda', 2019129789),
#  (2019128312, 'Tabajonda', 2019132627),
#  (2019128312, 'Tabajonda', 2019128089),
#  (2019128312, 'Tabajonda', 2019131905),
#  (2019128312, 'Tabajonda', 2019128151),
#  (2019128312, 'Tabajonda', 2018117965),
#  (2019128312, 'Tabajonda', 2019128312),
#  (2019128312, 'Tabajonda', 2019128272),
#  (2019128312, 'Tabajonda', 2019128232),
#  (2019128312, 'Tabajonda', 2015081794),
#  (2019128312, 'Tabajonda', 2019128253),
#  (2019128312, 'Tabajonda', 2019127901),
#  (2019128312, 'Tabajonda', 2019128145),
#  (2019128312, 'Tabajonda', 2019128203),
#  (2019128312, 'Tabajonda', 2019128149),
#  (2019128312, 'Tabajonda', 2019128005),
#  (2019128312, 'Tabajonda', 2019128314),
#  (2019128312, 'Tabajonda', 2019127972),
#  (2019128312, 'Tabajonda', 2019128026),
#  (2019128312, 'Tabajonda', 2019131291),
#  (2019128312, 'Tabajonda', 2019131907),
#  (2019128312, 'Tabajonda', 2019128213),
#  (2019128272, 'Sindayen', 2018107987),
#  (2019128272, 'Sindayen', 2019130134),
#  (2019128272, 'Sindayen', 2019132083),
#  (2019128272, 'Sindayen', 2019129789),
#  (2019128272, 'Sindayen', 2019132627),
#  (2019128272, 'Sindayen', 2019128089),
#  (2019128272, 'Sindayen', 2019131905),
#  (2019128272, 'Sindayen', 2019128151),
#  (2019128272, 'Sindayen', 2018117965),
#  (2019128272, 'Sindayen', 2019128312),
#  (2019128272, 'Sindayen', 2019128272),
#  (2019128272, 'Sindayen', 2019128232),
#  (2019128272, 'Sindayen', 2015081794),
#  (2019128272, 'Sindayen', 2019128253),
#  (2019128272, 'Sindayen', 2019127901),
#  (2019128272, 'Sindayen', 2019128145),
#  (2019128272, 'Sindayen', 2019128203),
#  (2019128272, 'Sindayen', 2019128149),
#  (2019128272, 'Sindayen', 2019128005),
#  (2019128213, 'Ilas', 2018117965),
#  (2019128213, 'Ilas', 2019128312),
#  (2019128213, 'Ilas', 2019128272),
#  (2019128213, 'Ilas', 2019128232),
#  (2019128213, 'Ilas', 2015081794),
#  (2019128213, 'Ilas', 2019128253),
#  (2019128213, 'Ilas', 2019127901),
#  (2019128213, 'Ilas', 2019128145),
#  (2019128213, 'Ilas', 2019128203),
#  (2019128213, 'Ilas', 2019128149),
#  (2019128213, 'Ilas', 2019128005),
#  (2019128213, 'Ilas', 2019128314),
#  (2019128213, 'Ilas', 2019127972),
#  (2019128213, 'Ilas', 2019128026),
#  (2019128213, 'Ilas', 2019131291),
#  (2019128213, 'Ilas', 2019131907),
#  (2019128213, 'Ilas', 2019128213)]

# %%
query = ('''
SELECT 
    id, age, gwa
    FROM students_3csc 
UNION
SELECT 
    applicant_no, jhs_gwa, shs_gwa
    FROM students_3csc_grades
''')
pd.read_sql(query, conn)
# Out:
#             id    age    gwa
# 0   2018117965  21.00   2.00
# 1   2019128272  20.00   2.00
# 2   2019130134  88.88  77.77
# 3   2019128203  84.00  90.00
# 4   2018107987  91.00  94.00
# 5   2019128312  91.00  92.00
# 6   2019128314  90.00  90.00
# 7   2019132627  90.00  91.00
# 8   2019131907  20.00   1.01
# 9   2018117965  89.68  91.36
# 10  2019128314  21.00   3.00
# 11  2019131905  20.00   1.00
# 12  2019131907  89.00  99.00
# 13  2019128232  21.00   3.14
# 14  2019129789  96.00  97.00
# 15  2019128026  21.00   3.00
# 16  2019132083  91.42  93.00
# 17  2019128145  20.00   1.00
# 18  2019128253  91.00  91.00
# 19  2019127901  92.00  89.00
# 20  2019129789  21.00   5.00
# 21  2019130134  20.00   4.20
# 22  2019128089  20.00   4.20
# 23  2019131291  90.00  87.00
# 24  2019128005  76.00  77.00
# 25  2019128203  21.00   3.00
# 26  2019128149  75.00  75.00
# 27  2015081794  90.00  95.00
# 28  2019128312  21.00   1.00
# 29  2019127972  20.00   1.00
# 30  2019132083  20.00   5.00
# 31  2019131905  90.00  90.00
# 32  2019127901  20.00   3.00
# 33  2019128005  20.00   5.00
# 34  2019128145  91.00  94.00
# 35  2019128232  87.50  88.90
# 36  2019128151  94.17  93.24
# 37  2019128026  85.00  85.00
# 38  2019128089  80.08  96.69
# 39  2019128272  86.00  92.00
# 40  2019128151  20.00   5.00
# 41  2019128213  21.00   2.00
# 42  2019128213  84.00  91.00
# 43  2018107987  21.00   1.69
# 44  2019128149  19.00   5.00
# 45  2019128253  20.00   2.00
# 46  2019131291  20.00   2.00
# 47  2015081794  22.00   5.00
# 48  2019132627  20.00   2.00
# 49  2019127972  87.00  85.00

# %%
query = ('''
SELECT 
    id, gwa
    FROM students_3csc 
UNION ALL
SELECT 
    applicant_no, ustet_score
    FROM students_3csc_grades
''')
pd.read_sql(query, conn)
# Out:
#             id    gwa
# 0   2018107987   1.69
# 1   2019130134   4.20
# 2   2019132083   5.00
# 3   2019129789   5.00
# 4   2019132627   2.00
# 5   2019128089   4.20
# 6   2019131905   1.00
# 7   2019128151   5.00
# 8   2018117965   2.00
# 9   2019128312   1.00
# 10  2019128272   2.00
# 11  2019128232   3.14
# 12  2015081794   5.00
# 13  2019128253   2.00
# 14  2019127901   3.00
# 15  2019128145   1.00
# 16  2019128203   3.00
# 17  2019128149   5.00
# 18  2019128005   5.00
# 19  2019128314   3.00
# 20  2019127972   1.00
# 21  2019128026   3.00
# 22  2019131291   2.00
# 23  2019131907   1.01
# 24  2019128213   2.00
# 25  2018107987  80.00
# 26  2019130134  69.00
# 27  2019132083  87.00
# 28  2019129789  95.00
# 29  2019132627  88.00
# 30  2019128089  69.42
# 31  2019131905  90.00
# 32  2019128151  97.00
# 33  2018117965  88.00
# 34  2019128312  90.00
# 35  2019128272  85.00
# 36  2019128232  92.00
# 37  2015081794  85.00
# 38  2019128253  91.00
# 39  2019127901  85.00
# 40  2019128145  90.00
# 41  2019128203  96.00
# 42  2019128149  76.00
# 43  2019128005  75.00
# 44  2019128314  89.00
# 45  2019127972  90.00
# 46  2019128026  85.00
# 47  2019131291  89.50
# 48  2019131907  79.00
# 49  2019128213  86.00

# %%
query = ('''
SELECT 
    id
    FROM students_3csc 
INTERSECT
SELECT 
    applicant_no
    FROM students_3csc_grades
''')
pd.read_sql(query, conn)
# Out:
#             id
# 0   2019128213
# 1   2019131905
# 2   2019128253
# 3   2019128149
# 4   2019128312
# 5   2019128089
# 6   2019130134
# 7   2019129789
# 8   2019132083
# 9   2019128314
# 10  2019127901
# 11  2019132627
# 12  2019128005
# 13  2018107987
# 14  2019128026
# 15  2019131907
# 16  2019128145
# 17  2018117965
# 18  2015081794
# 19  2019128151
# 20  2019131291
# 21  2019128232
# 22  2019128272
# 23  2019127972
# 24  2019128203

# %%
query = ('''
    SELECT 
    id, gender, gwa, avg(gwa)
    FROM students_3csc 
    GROUP BY id, gender, gwa
''')
c.execute(query)
c.fetchall()
# Out:
# [(2019128213, 'M', 2.0, 2.0),
#  (2019131905, 'M', 1.0, 1.0),
#  (2019128253, 'F', 2.0, 2.0),
#  (2019128149, 'M', 5.0, 5.0),
#  (2019128312, 'M', 1.0, 1.0),
#  (2019128089, 'M', 4.2, 4.2),
#  (2019130134, 'M', 4.2, 4.2),
#  (2019129789, 'F', 5.0, 5.0),
#  (2019132083, 'M', 5.0, 5.0),
#  (2019128314, 'M', 3.0, 3.0),
#  (2019127901, 'M', 3.0, 3.0),
#  (2019132627, 'M', 2.0, 2.0),
#  (2019128005, 'M', 5.0, 5.0),
#  (2018107987, 'M', 1.69, 1.69),
#  (2019128026, 'M', 3.0, 3.0),
#  (2019131907, 'M', 1.01, 1.01),
#  (2019128145, 'F', 1.0, 1.0),
#  (2018117965, 'M', 2.0, 2.0),
#  (2015081794, 'M', 5.0, 5.0),
#  (2019128151, 'M', 5.0, 5.0),
#  (2019131291, 'F', 2.0, 2.0),
#  (2019128232, 'M', 3.14, 3.14),
#  (2019128272, 'M', 2.0, 2.0),
#  (2019127972, 'M', 1.0, 1.0),
#  (2019128203, 'M', 3.0, 3.0)]

# %%
query = ('''
    SELECT 
    gender, AVG(gwa)
    FROM students_3csc 
    GROUP BY gender
''')
c.execute(query)
c.fetchall()
# Out:
# [('M', 2.963809523809524), ('F', 2.5)]

# %%
query = ('''
    SELECT 
    age, AVG(gwa)
    FROM students_3csc 
    GROUP BY age
    ORDER BY avg(gwa) desc
''')
c.execute(query)
c.fetchall()
# Out:
# [(19, 5.0), (22, 5.0), (20, 2.7435714285714283), (21, 2.647777777777778)]

# %%
query = ('''
    SELECT 
    strand, ustet_score, COUNT(shs_gwa)
    FROM students_3csc_grades 
    GROUP BY CUBE(strand, ustet_score)
''')
pd.read_sql(query, conn)
# Out:
#    strand  ustet_score  count
# 0    None          NaN     25
# 1    STEM        88.00      1
# 2    STEM        89.00      1
# 3    STEM        87.00      1
# 4     ABM        97.00      1
# 5    STEM        76.00      1
# 6    STEM        86.00      1
# 7    STEM        96.00      1
# 8    STEM        91.00      1
# 9   HUMMS        85.00      1
# 10    MAD        79.00      1
# 11    ICT        85.00      1
# 12    ABM        88.00      1
# 13    ABM        80.00      1
# 14   STEM        75.00      1
# 15   STEM        92.00      1
# 16   STEM        69.42      1
# 17   STEM        69.00      1
# 18   STEM        90.00      3
# 19   STEM        85.00      1
# 20   PEST        85.00      1
# 21    ABM        89.50      1
# 22    ABM        90.00      1
# 23    GAS        95.00      1
# 24  HUMMS          NaN      1
# 25    ICT          NaN      1
# 26    ABM          NaN      5
# 27   STEM          NaN     15
# 28    MAD          NaN      1
# 29   PEST          NaN      1
# 30    GAS          NaN      1
# 31   None        76.00      1
# 32   None        96.00      1
# 33   None        86.00      1
# 34   None        85.00      4
# 35   None        80.00      1
# 36   None        75.00      1
# 37   None        91.00      1
# 38   None        69.42      1
# 39   None        88.00      2
# 40   None        79.00      1
# 41   None        92.00      1
# 42   None        90.00      4
# 43   None        97.00      1
# 44   None        87.00      1
# 45   None        69.00      1
# 46   None        89.50      1
# 47   None        89.00      1
# 48   None        95.00      1

# %%
query = ('''
    SELECT 
    strand, ustet_score, jhs_gwa, SUM(ustet_score)
    FROM students_3csc_grades 
    GROUP BY strand, CUBE(ustet_score, jhs_gwa) ORDER BY strand
''')
pd.read_sql(query, conn)
# Out:
#    strand  ustet_score  jhs_gwa   sum
# 0     ABM         97.0    94.17  97.0
# 1     ABM         88.0    89.68  88.0
# 2     ABM          NaN    94.17  97.0
# 3     ABM          NaN    90.00  89.5
# 4     ABM         90.0    91.00  90.0
# ..    ...          ...      ...   ...
# 70   STEM         96.0      NaN  96.0
# 71   STEM         91.0      NaN  91.0
# 72   STEM         90.0    90.00  90.0
# 73   STEM         75.0      NaN  75.0
# 74   STEM         92.0      NaN  92.0
#
# [75 rows x 4 columns]

# %%
#NaN is for numerical and None is for categorica
query = ('''
    SELECT 
    strand, ustet_score, jhs_gwa, SUM(ustet_score), COUNT(strand)
    FROM students_3csc_grades 
    GROUP BY strand, jhs_gwa, CUBE(ustet_score) ORDER BY strand
''')
pd.read_sql(query, conn)
# Out:
#    strand  ustet_score  jhs_gwa     sum  count
# 0     ABM        88.00    89.68   88.00      1
# 1     ABM        80.00    91.00   80.00      1
# 2     ABM          NaN    91.00  170.00      2
# 3     ABM          NaN    89.68   88.00      1
# 4     ABM        97.00    94.17   97.00      1
# 5     ABM        90.00    91.00   90.00      1
# 6     ABM        89.50    90.00   89.50      1
# 7     ABM          NaN    94.17   97.00      1
# 8     ABM          NaN    90.00   89.50      1
# 9     GAS          NaN    96.00   95.00      1
# 10    GAS        95.00    96.00   95.00      1
# 11  HUMMS        85.00    90.00   85.00      1
# 12  HUMMS          NaN    90.00   85.00      1
# 13    ICT          NaN    85.00   85.00      1
# 14    ICT        85.00    85.00   85.00      1
# 15    MAD          NaN    89.00   79.00      1
# 16    MAD        79.00    89.00   79.00      1
# 17   PEST          NaN    86.00   85.00      1
# 18   PEST        85.00    86.00   85.00      1
# 19   STEM        90.00    87.00   90.00      1
# 20   STEM        90.00    91.00   90.00      1
# 21   STEM        75.00    76.00   75.00      1
# 22   STEM        88.00    90.00   88.00      1
# 23   STEM        96.00    84.00   96.00      1
# 24   STEM          NaN    87.00   90.00      1
# 25   STEM        89.00    90.00   89.00      1
# 26   STEM          NaN    76.00   75.00      1
# 27   STEM        69.00    88.88   69.00      1
# 28   STEM        92.00    87.50   92.00      1
# 29   STEM          NaN    84.00  182.00      2
# 30   STEM          NaN    80.08   69.42      1
# 31   STEM        85.00    92.00   85.00      1
# 32   STEM        91.00    91.00   91.00      1
# 33   STEM          NaN    75.00   76.00      1
# 34   STEM          NaN    92.00   85.00      1
# 35   STEM        76.00    75.00   76.00      1
# 36   STEM          NaN    88.88   69.00      1
# 37   STEM          NaN    90.00  267.00      3
# 38   STEM          NaN    87.50   92.00      1
# 39   STEM          NaN    91.42   87.00      1
# 40   STEM        69.42    80.08   69.42      1
# 41   STEM          NaN    91.00  181.00      2
# 42   STEM        87.00    91.42   87.00      1
# 43   STEM        86.00    84.00   86.00      1
# 44   STEM        90.00    90.00   90.00      1

# %%
#NaN is for numerical and None is for categorica
query = ('''
    SELECT 
    gender, gwa, age, AVG(gwa)
    FROM students_3csc
    GROUP BY ROLLUP(gender, gwa, age)
''')
pd.read_sql(query, conn)
# Out:
#    gender   gwa   age      avg
# 0    None   NaN   NaN  2.88960
# 1       M  4.20  20.0  4.20000
# 2       M  1.00  21.0  1.00000
# 3       M  1.01  20.0  1.01000
# 4       M  3.00  20.0  3.00000
# 5       M  5.00  22.0  5.00000
# 6       M  5.00  19.0  5.00000
# 7       M  3.14  21.0  3.14000
# 8       M  1.69  21.0  1.69000
# 9       F  5.00  21.0  5.00000
# 10      F  1.00  20.0  1.00000
# 11      F  2.00  20.0  2.00000
# 12      M  2.00  21.0  2.00000
# 13      M  5.00  20.0  5.00000
# 14      M  1.00  20.0  1.00000
# 15      M  3.00  21.0  3.00000
# 16      M  2.00  20.0  2.00000
# 17      M  3.00   NaN  3.00000
# 18      M  3.14   NaN  3.14000
# 19      F  5.00   NaN  5.00000
# 20      M  1.01   NaN  1.01000
# 21      M  1.00   NaN  1.00000
# 22      M  5.00   NaN  5.00000
# 23      M  1.69   NaN  1.69000
# 24      M  4.20   NaN  4.20000
# 25      F  1.00   NaN  1.00000
# 26      F  2.00   NaN  2.00000
# 27      M  2.00   NaN  2.00000
# 28      M   NaN   NaN  2.96381
# 29      F   NaN   NaN  2.50000

# %%
#NaN is for numerical and None is for categorica
query = ('''
    SELECT 
    gender, gwa, age, AVG(gwa)
    FROM students_3csc
    GROUP BY ROLLUP(gender, gwa, age)
    ORDER BY gender
''')
pd.read_sql(query, conn)
# Out:
#    gender   gwa   age      avg
# 0       F  1.00  20.0  1.00000
# 1       F  1.00   NaN  1.00000
# 2       F  2.00  20.0  2.00000
# 3       F  2.00   NaN  2.00000
# 4       F  5.00  21.0  5.00000
# 5       F  5.00   NaN  5.00000
# 6       F   NaN   NaN  2.50000
# 7       M  1.00  20.0  1.00000
# 8       M  1.00  21.0  1.00000
# 9       M  1.00   NaN  1.00000
# 10      M  1.01  20.0  1.01000
# 11      M  1.01   NaN  1.01000
# 12      M  1.69  21.0  1.69000
# 13      M  1.69   NaN  1.69000
# 14      M  2.00  20.0  2.00000
# 15      M  2.00  21.0  2.00000
# 16      M  2.00   NaN  2.00000
# 17      M  3.00  20.0  3.00000
# 18      M  3.00  21.0  3.00000
# 19      M  3.00   NaN  3.00000
# 20      M  3.14  21.0  3.14000
# 21      M  3.14   NaN  3.14000
# 22      M  4.20  20.0  4.20000
# 23      M  4.20   NaN  4.20000
# 24      M  5.00  19.0  5.00000
# 25      M  5.00  20.0  5.00000
# 26      M  5.00  22.0  5.00000
# 27      M  5.00   NaN  5.00000
# 28      M   NaN   NaN  2.96381
# 29   None   NaN   NaN  2.88960

# %%
#NaN is for numerical and None is for categorical
query = ('''
    SELECT 
    gender, gwa, age, AVG(gwa)
    FROM students_3csc
    GROUP BY gender, age, ROLLUP(gwa)
    ORDER BY gender
''')
pd.read_sql(query, conn)
# Out:
#    gender   gwa  age       avg
# 0       F  1.00   20  1.000000
# 1       F  2.00   20  2.000000
# 2       F   NaN   20  1.666667
# 3       F  5.00   21  5.000000
# 4       F   NaN   21  5.000000
# 5       M  5.00   19  5.000000
# 6       M   NaN   19  5.000000
# 7       M  1.00   20  1.000000
# 8       M  1.01   20  1.010000
# 9       M  2.00   20  2.000000
# 10      M  3.00   20  3.000000
# 11      M  4.20   20  4.200000
# 12      M  5.00   20  5.000000
# 13      M   NaN   20  3.037273
# 14      M  1.00   21  1.000000
# 15      M  1.69   21  1.690000
# 16      M  2.00   21  2.000000
# 17      M  3.00   21  3.000000
# 18      M  3.14   21  3.140000
# 19      M   NaN   21  2.353750
# 20      M  5.00   22  5.000000
# 21      M   NaN   22  5.000000

# %%
#NaN is for numerical and None is for categorical
query = ('''
    SELECT 
    gender, gwa, age, AVG(gwa)
    FROM students_3csc
    WHERE age > 20 AND gwa < 2
    GROUP BY gender, age, ROLLUP(gwa)
    ORDER BY gender
''')
pd.read_sql(query, conn)
# Out:
#   gender   gwa  age    avg
# 0      M  1.00   21  1.000
# 1      M  1.69   21  1.690
# 2      M   NaN   21  1.345
