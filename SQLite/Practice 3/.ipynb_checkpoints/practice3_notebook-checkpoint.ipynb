# %%
import sqlite3 as sql
import pandas as pd

# %%
conn = sql.connect('practice3.db')

# %%
cursor = conn.cursor()

# %%
cursor.execute('CREATE TABLE "sales" ("Product_ID" REAL,"Transaction_date" TEXT,"Product" TEXT,"Price" TEXT,"Payment_Type" TEXT,"Name" TEXT,"City" TEXT,"State" TEXT,"Country" TEXT)')

# %%
conn.commit()

# %%
data = [(10000, '1/1/09 4:24', 'Product3', 7500, 'Amex', 'Pamela', 'Skaneateles', 'NY', 'United States'), 
        (10001, '1/8/09 11:55', 'Product1', 1200, 'Diners', 'julie', 'Haverhil', 'England', 'United Kingdom'), 
        (10002, '1/12/09 21:30', 'Product1', 1200, 'Visa', 'Julia', 'Madison', 'WI', 'United States'),
       ]

# %%
cursor.executemany('INSERT INTO sales VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?)', data)

# %%
conn.commit()

# %%
cursor.execute('DELETE FROM sales')

# %%
df = pd.read_sql_query('SELECT * FROM sales', conn)
df
# Out:
#    Product_ID Transaction_date   Product Price Payment_Type    Name  \
# 0     10000.0      1/1/09 4:24  Product3  7500         Amex  Pamela
# 1     10001.0     1/8/09 11:55  Product1  1200       Diners   julie
# 2     10002.0    1/12/09 21:30  Product1  1200         Visa   Julia
#
#           City    State         Country
# 0  Skaneateles       NY   United States
# 1     Haverhil  England  United Kingdom
# 2      Madison       WI   United States

# %%
additional_data = [
                (10003, '1/26/09 13:41', 'Product1', 1200, 'Mastercard', 'Lesleigh', 'Baden', 'Aargau', 'Switzerland'),
                (10004, '1/20/09 10:42', 'Product2', 3600, 'Diners', 'esther', 'Huddersfield', 'England', 'United Kingdom'),
                (10005, '1/22/09 14:25', 'Product1', 1200, 'Visa', 'Hans-Joerg', 'Belfast', 'Northern Ireland', 'United Kingdom'),
                (10006, '1/28/09 5:36', 'Product2', 3600, 'Visa', 'Christiane', 'Black River', 'Black River', 'Mauritius'),
                ]

# %%
cursor.executemany('INSERT INTO sales VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?)', additional_data)

# %%
conn.commit()

# %%
pd.read_sql_query('SELECT * FROM sales LIMIT 4', conn)
# Out:
#    Product_ID Transaction_date   Product Price Payment_Type      Name  \
# 0     10000.0      1/1/09 4:24  Product3  7500         Amex    Pamela
# 1     10001.0     1/8/09 11:55  Product1  1200       Diners     julie
# 2     10002.0    1/12/09 21:30  Product1  1200         Visa     Julia
# 3     10003.0    1/26/09 13:41  Product1  1200   Mastercard  Lesleigh
#
#           City    State         Country
# 0  Skaneateles       NY   United States
# 1     Haverhil  England  United Kingdom
# 2      Madison       WI   United States
# 3        Baden   Aargau     Switzerland

# %%
pd.read_sql_query('SELECT * FROM sales', conn)
# Out:
#    Product_ID Transaction_date   Product Price Payment_Type        Name  \
# 0     10000.0      1/1/09 4:24  Product3  7500         Amex      Pamela
# 1     10001.0     1/8/09 11:55  Product1  1200       Diners       julie
# 2     10002.0    1/12/09 21:30  Product1  1200         Visa       Julia
# 3     10003.0    1/26/09 13:41  Product1  1200   Mastercard    Lesleigh
# 4     10004.0    1/20/09 10:42  Product2  3600       Diners      esther
# 5     10005.0    1/22/09 14:25  Product1  1200         Visa  Hans-Joerg
# 6     10006.0     1/28/09 5:36  Product2  3600         Visa  Christiane
#
#            City             State         Country
# 0   Skaneateles                NY   United States
# 1      Haverhil           England  United Kingdom
# 2       Madison                WI   United States
# 3         Baden            Aargau     Switzerland
# 4  Huddersfield           England  United Kingdom
# 5       Belfast  Northern Ireland  United Kingdom
# 6   Black River       Black River       Mauritius

# %%
pd.read_sql_query('SELECT Name, Country FROM sales', conn)
# Out:
#          Name         Country
# 0      Pamela   United States
# 1       julie  United Kingdom
# 2       Julia   United States
# 3    Lesleigh     Switzerland
# 4      esther  United Kingdom
# 5  Hans-Joerg  United Kingdom
# 6  Christiane       Mauritius

# %%
pd.read_sql_query('SELECT Product, Payment_Type FROM sales WHERE Price < 3000', conn)
# Out:
#     Product Payment_Type
# 0  Product1       Diners
# 1  Product1         Visa
# 2  Product1   Mastercard
# 3  Product1         Visa

# %%
variable = pd.read_csv('Sales - Sales.csv')

# %%
variable.to_sql('sales', con = conn, index=False, if_exists = 'append')

# %%
pd.read_sql_query('SELECT * FROM sales LIMIT 10', conn)
# Out:
#    Product_ID Transaction_date   Product Price Payment_Type  \
# 0     10000.0      1/1/09 4:24  Product3  7500         Amex
# 1     10001.0     1/8/09 11:55  Product1  1200       Diners
# 2     10002.0    1/12/09 21:30  Product1  1200         Visa
# 3     10003.0    1/26/09 13:41  Product1  1200   Mastercard
# 4     10004.0    1/20/09 10:42  Product2  3600       Diners
# 5     10005.0    1/22/09 14:25  Product1  1200         Visa
# 6     10006.0     1/28/09 5:36  Product2  3600         Visa
# 7         NaN      1/2/09 6:17  Product1  1200   Mastercard
# 8     10008.0      1/2/09 4:53  Product1  1200         Visa
# 9     10009.0     1/2/09 13:08  Product1  1200   Mastercard
#
#                 Name          City             State         Country
# 0             Pamela   Skaneateles                NY   United States
# 1              julie      Haverhil           England  United Kingdom
# 2              Julia       Madison                WI   United States
# 3           Lesleigh         Baden            Aargau     Switzerland
# 4             esther  Huddersfield           England  United Kingdom
# 5         Hans-Joerg       Belfast  Northern Ireland  United Kingdom
# 6         Christiane   Black River       Black River       Mauritius
# 7           carolina      Basildon           England  United Kingdom
# 8             Betina     Parkville                MO   United States
# 9  Federica e Andrea       Astoria                OR   United States

# %%
pd.read_sql_query('SELECT Name, Country FROM sales LIMIT 10', conn)
# Out:
#                 Name         Country
# 0             Pamela   United States
# 1              julie  United Kingdom
# 2              Julia   United States
# 3           Lesleigh     Switzerland
# 4             esther  United Kingdom
# 5         Hans-Joerg  United Kingdom
# 6         Christiane       Mauritius
# 7           carolina  United Kingdom
# 8             Betina   United States
# 9  Federica e Andrea   United States

# %%
pd.read_sql_query('SELECT Product, Payment_Type FROM sales WHERE Price > 4000', conn)
# Out:
#      Product Payment_Type
# 0   Product3         Amex
# 1   Product3   Mastercard
# 2   Product3   Mastercard
# 3   Product3         Visa
# 4   Product3         Visa
# 5   Product1         Amex
# 6   Product3   Mastercard
# 7   Product3         Visa
# 8   Product3         Visa
# 9   Product3         Visa
# 10  Product3         Visa
# 11  Product3   Mastercard
# 12  Product3   Mastercard
# 13  Product3       Diners
# 14  Product3       Diners
# 15  Product3         Visa
