# %%
import mysql.connector 
import pandas as pd

# %%
conn = mysql.connector.connect(
    host = "localhost", 
    user = "root", 
    password = "@Ngelo8998",
    database = "dw_3csc"
)

# %%
c = conn.cursor()

# %%
c.execute("""
    CREATE TABLE 
        students_3csc(id INT PRIMARY KEY NOT NULL, 
        firstname TEXT NOT NULL, 
        familyname TEXT NOT NULL, 
        age INT NOT NULL, 
        gwa REAL NOT NULL, 
        gender TEXT NOT NULL)
""")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'students_3csc' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-956f3af82885> in <module>
# ----> 1 c.execute("""
#       2     CREATE TABLE
#       3         students_3csc(id INT PRIMARY KEY NOT NULL,
#       4         firstname TEXT NOT NULL,
#       5         familyname TEXT NOT NULL,
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                          buffered=self._buffered,
#     271                                          raw_as_string=self._raw_as_string)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     519                                query_attrs=self._query_attrs)
#     520         except MySQLInterfaceError as exc:
# --> 521             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     522                                              sqlstate=exc.sqlstate)
#     523         except AttributeError:
#
# ProgrammingError: 1050 (42S01): Table 'students_3csc' already exists

# %%
conn.commit()

# %%
c.execute("""
    INSERT INTO 
        students_3csc
    VALUES
        (2018107987, 'John Louise', 'Lagazo', 21, 1.69, 'M')
""")

# %%
conn.commit()

# %%
c.execute("SELECT * FROM students_3csc")

# %%
c.fetchall()
# Out:
# [(2018107987, 'John Louise', 'Lagazo', 21, 1.69, 'M')]

# %%
test = [(2021193093, 'Louise', 'Legazpi', 19, 1.420, 'M')]

# %%
test_list = list(test)

# %%
c.executemany("""
    INSERT INTO 
        students_3csc
    VALUES
        (%s, %s, %s, %s, %s, %s)
""", test_list)

# %%
conn.commit()

# %%
id = input("id: ")
firstname = input("firstname: ")
familyname = input("familyname: ")
age = input("age: ")
gwa = input("gwa: ")
gender = input("gender: ")
# Out:
# id: 2022193082
# firstname: Karlo
# familyname: Llarinas
# age: 17
# gwa: 9
# gender: B

# %%
c.execute("""
    INSERT INTO 
        students_3csc
    VALUES
        (%s, %s, %s, %s, %s, %s)
""", (id, firstname, familyname, age, gwa, gender))

# %%
conn.commit()

# %%
df1 = pd.read_sql_query("SELECT * FROM students_3csc", conn)
df1
# Out:
#             id         firstname familyname  age   gwa gender
# 0   2015081794             Allen    Marders   22  5.00      M
# 1   2018107987       John Louise     Lagazo   21  1.69      M
# 2   2018117965       Carl Joseph       Paez   21  2.00      M
# 3   2019127901            Enrico      Oliva   20  3.00      M
# 4   2019127972  Kerwin Dominique     Aquino   20  1.00      M
# 5   2019128005          Dominick    Segundo   20  5.00      M
# 6   2019128026  Lorenz Christian      Tadeo   21  3.00      M
# 7   2019128089            Andrei    Benitez   20  4.20      M
# 8   2019128145       Jasmine Joy        Lam   20  1.00      F
# 9   2019128149             Rowel    Buluran   19  5.00      M
# 10  2019128151             Anton     Bondoc   20  5.00      M
# 11  2019128203             Ronan   Doncillo   21  3.00      M
# 12  2019128213          John Vic       Ilas   21  2.00      M
# 13  2019128232             Aaron     Santos   21  3.14      M
# 14  2019128253           Bridget      Plaza   20  2.00      F
# 15  2019128272             Carlo   Sindayen   20  2.00      M
# 16  2019128312              Karl  Tabajonda   21  1.00      M
# 17  2019128314             Franz       Amog   21  3.00      M
# 18  2019129789         Chlarizza     Torres   21  5.00      F
# 19  2019130134       John Angelo    Algarne   20  4.20      M
# 20  2019131291       Leira Marie    Teodoro   20  2.00      F
# 21  2019131905             Keane     Tejada   20  1.00      M
# 22  2019131907       Lester John   Quilaman   20  1.01      M
# 23  2019132083            Angelo      Hizon   20  5.00      M
# 24  2019132627          Abraham     Militar   20  2.00      M
# 25  2021193093            Louise    Legazpi   19  1.42      M

# %%
import csv
import csv as reader

# %%
# using csv reader
csc_g1 = open("3csc - csc_g1.csv")
g1_3csc = csv.reader(csc_g1)
g1_3csc

# %%
# creating a list
g1 = list(csv.reader(csc_g1))
g1
# Out:
# [['2019130134', 'John Angelo', 'Algarne', '20', '4.2', 'M'],
#  ['2019132083', 'Angelo', 'Hizon', '20', '5', 'M'],
#  ['2019129789', 'Chlarizza', 'Torres', '21', '5', 'F'],
#  ['2019132627', 'Abraham ', 'Militar', '20', '2', 'M'],
#  ['2019128089', 'Andrei', 'Benitez', '20', '4.2', 'M'],
#  ['2019131905', 'Keane', 'Tejada', '20', '1', 'M'],
#  ['2019128151', 'Anton', 'Bondoc', '20', '5', 'M'],
#  ['2018117965', 'Carl Joseph', 'Paez', '21', '2', 'M'],
#  ['2019128312', 'Karl', 'Tabajonda', '21', '1', 'M'],
#  ['2019128272', 'Carlo', 'Sindayen', '20', '2', 'M'],
#  ['2019128232', 'Aaron', 'Santos', '21', '3.14', 'M'],
#  ['2015081794', 'Allen', 'Marders', '22', '5', 'M'],
#  ['2019128253', 'Bridget', 'Plaza', '20', '2', 'F']]

# %%
c.executemany("""
    INSERT INTO students_3csc VALUES(%s, %s, %s, %s, %s, %s)
""", g1)

# %%
conn.commit()

# %%
df_g1 = pd.read_sql_query("SELECT * FROM students_3csc", conn)
df_g1
# Out:
#             id    firstname familyname  age   gwa gender
# 0   2015081794        Allen    Marders   22  5.00      M
# 1   2018107987  John Louise     Lagazo   21  1.69      M
# 2   2018117965  Carl Joseph       Paez   21  2.00      M
# 3   2019128089       Andrei    Benitez   20  4.20      M
# 4   2019128151        Anton     Bondoc   20  5.00      M
# 5   2019128232        Aaron     Santos   21  3.14      M
# 6   2019128253      Bridget      Plaza   20  2.00      F
# 7   2019128272        Carlo   Sindayen   20  2.00      M
# 8   2019128312         Karl  Tabajonda   21  1.00      M
# 9   2019129789    Chlarizza     Torres   21  5.00      F
# 10  2019130134  John Angelo    Algarne   20  4.20      M
# 11  2019131905        Keane     Tejada   20  1.00      M
# 12  2019132083       Angelo      Hizon   20  5.00      M
# 13  2019132627     Abraham     Militar   20  2.00      M

# %%
csc_g2 = open("3csc - csc_g2.csv")
g2_3csc = csv.reader(csc_g2)
g2_3csc

# %%
# creating a list
g2 = list(g2_3csc)
g2
# Out:
# [['2019127901', 'Enrico', 'Oliva', '20', '3', 'M'],
#  ['2019128145', 'Jasmine Joy', 'Lam', '20', '1', 'F'],
#  ['2019128203', 'Ronan', 'Doncillo', '21', '3', 'M'],
#  ['2019128149', 'Rowel', 'Buluran', '19', '5', 'M'],
#  ['2019128005', 'Dominick', 'Segundo', '20', '5', 'M'],
#  ['2019128314', 'Franz', 'Amog', '21', '3', 'M'],
#  ['2019127972', 'Kerwin Dominique', 'Aquino', '20', '1', 'M'],
#  ['2019128026', 'Lorenz Christian', 'Tadeo', '21', '3', 'M'],
#  ['2019131291', 'Leira Marie', 'Teodoro', '20', '2', 'F'],
#  ['2019128213', 'John Vic', 'Ilas', '21', '2', 'M'],
#  ['2019131907', 'Lester John', 'Quilaman', '20', '1.01', 'M']]

# %%
c.executemany("""
    INSERT INTO students_3csc VALUES(%s, %s, %s, %s, %s, %s)
""", g2)

# %%
df_g1_and_g2 = pd.read_sql_query("SELECT * FROM students_3csc", conn)
df_g1_and_g2
# Out:
#             id         firstname familyname  age   gwa gender
# 0   2015081794             Allen    Marders   22  5.00      M
# 1   2018107987       John Louise     Lagazo   21  1.69      M
# 2   2018117965       Carl Joseph       Paez   21  2.00      M
# 3   2019127901            Enrico      Oliva   20  3.00      M
# 4   2019127972  Kerwin Dominique     Aquino   20  1.00      M
# 5   2019128005          Dominick    Segundo   20  5.00      M
# 6   2019128026  Lorenz Christian      Tadeo   21  3.00      M
# 7   2019128089            Andrei    Benitez   20  4.20      M
# 8   2019128145       Jasmine Joy        Lam   20  1.00      F
# 9   2019128149             Rowel    Buluran   19  5.00      M
# 10  2019128151             Anton     Bondoc   20  5.00      M
# 11  2019128203             Ronan   Doncillo   21  3.00      M
# 12  2019128213          John Vic       Ilas   21  2.00      M
# 13  2019128232             Aaron     Santos   21  3.14      M
# 14  2019128253           Bridget      Plaza   20  2.00      F
# 15  2019128272             Carlo   Sindayen   20  2.00      M
# 16  2019128312              Karl  Tabajonda   21  1.00      M
# 17  2019128314             Franz       Amog   21  3.00      M
# 18  2019129789         Chlarizza     Torres   21  5.00      F
# 19  2019130134       John Angelo    Algarne   20  4.20      M
# 20  2019131291       Leira Marie    Teodoro   20  2.00      F
# 21  2019131905             Keane     Tejada   20  1.00      M
# 22  2019131907       Lester John   Quilaman   20  1.01      M
# 23  2019132083            Angelo      Hizon   20  5.00      M
# 24  2019132627          Abraham     Militar   20  2.00      M

# %%
c.execute("""
    CREATE TABLE info2(
        applicant_no INT NOT NULL PRIMARY KEY,
        ustet_score REAL NOT NULL,
        jhs_gwa REAL NOT NULL,
        shs_gwa REAL NOT NULL, 
        strand TEXT NOT NULL
    )
""")

# %%
conn.commit()

# %%
# using csv reader
csc_info = open("3csc - csc_info2.csv")
info_3csc = csv.reader(csc_info)
info_3csc

# %%
# creating a list
info = list(info_3csc)
info
# Out:
# [['2018107987', '80', '91', '94', 'ABM'],
#  ['2019130134', '69', '88.88', '77.77', 'STEM'],
#  ['2019132083', '87', '91.42', '93', 'STEM'],
#  ['2019129789', '95', '96', '97', 'GAS'],
#  ['2019132627', '88', '90', '91', 'STEM'],
#  ['2019128089', '69.42', '80.08', '96.69', 'STEM'],
#  ['2019131905', '90', '90', '90', 'STEM'],
#  ['2019128151', '97', '94.17', '93.24', 'ABM'],
#  ['2018117965', '88', '89.68', '91.36', 'ABM'],
#  ['2019128312', '90', '91', '92', 'ABM'],
#  ['2019128272', '85', '86', '92', 'PEST'],
#  ['2019128232', '92', '87.5', '88.9', 'STEM'],
#  ['2015081794', '85', '90', '95', 'HUMMS'],
#  ['2019128253', '91', '91', '91', 'STEM'],
#  ['2019127901', '85', '92', '89', 'STEM'],
#  ['2019128145', '90', '91', '94', 'STEM'],
#  ['2019128203', '96', '84', '90', 'STEM'],
#  ['2019128149', '76', '75', '75', 'STEM'],
#  ['2019128005', '75', '76', '77', 'STEM'],
#  ['2019128314', '89', '90', '90', 'STEM'],
#  ['2019127972', '90', '87', '85', 'STEM'],
#  ['2019128026', '85', '85', '85', 'ICT'],
#  ['2019131291', '89.5', '90', '87', 'ABM'],
#  ['2019128213', '86', '84', '91', 'STEM'],
#  ['2019131907', '79', '89', '99', 'MAD']]

# %%
c.executemany("""
    INSERT INTO info2 VALUES(%s, %s, %s, %s, %s)
""", info)

# %%
complete_info2 = pd.read_sql_query("SELECT * FROM info2", conn)
complete_info2
# Out:
#     applicant_no  ustet_score  jhs_gwa  shs_gwa strand
# 0     2015081794        85.00    90.00    95.00  HUMMS
# 1     2018107987        80.00    91.00    94.00    ABM
# 2     2018117965        88.00    89.68    91.36    ABM
# 3     2019127901        85.00    92.00    89.00   STEM
# 4     2019127972        90.00    87.00    85.00   STEM
# 5     2019128005        75.00    76.00    77.00   STEM
# 6     2019128026        85.00    85.00    85.00    ICT
# 7     2019128089        69.42    80.08    96.69   STEM
# 8     2019128145        90.00    91.00    94.00   STEM
# 9     2019128149        76.00    75.00    75.00   STEM
# 10    2019128151        97.00    94.17    93.24    ABM
# 11    2019128203        96.00    84.00    90.00   STEM
# 12    2019128213        86.00    84.00    91.00   STEM
# 13    2019128232        92.00    87.50    88.90   STEM
# 14    2019128253        91.00    91.00    91.00   STEM
# 15    2019128272        85.00    86.00    92.00   PEST
# 16    2019128312        90.00    91.00    92.00    ABM
# 17    2019128314        89.00    90.00    90.00   STEM
# 18    2019129789        95.00    96.00    97.00    GAS
# 19    2019130134        69.00    88.88    77.77   STEM
# 20    2019131291        89.50    90.00    87.00    ABM
# 21    2019131905        90.00    90.00    90.00   STEM
# 22    2019131907        79.00    89.00    99.00    MAD
# 23    2019132083        87.00    91.42    93.00   STEM
# 24    2019132627        88.00    90.00    91.00   STEM

# %%
conn.commit()

# %%
query = """
    SELECT 
        *
    FROM 
        students_3csc 
    INNER JOIN
        info2
    ON
        id = applicant_no
"""
inner_join = pd.read_sql_query(query, conn)
inner_join
# Out:
#             id         firstname familyname  age   gwa gender  applicant_no  \
# 0   2015081794             Allen    Marders   22  5.00      M    2015081794
# 1   2018107987       John Louise     Lagazo   21  1.69      M    2018107987
# 2   2018117965       Carl Joseph       Paez   21  2.00      M    2018117965
# 3   2019127901            Enrico      Oliva   20  3.00      M    2019127901
# 4   2019127972  Kerwin Dominique     Aquino   20  1.00      M    2019127972
# 5   2019128005          Dominick    Segundo   20  5.00      M    2019128005
# 6   2019128026  Lorenz Christian      Tadeo   21  3.00      M    2019128026
# 7   2019128089            Andrei    Benitez   20  4.20      M    2019128089
# 8   2019128145       Jasmine Joy        Lam   20  1.00      F    2019128145
# 9   2019128149             Rowel    Buluran   19  5.00      M    2019128149
# 10  2019128151             Anton     Bondoc   20  5.00      M    2019128151
# 11  2019128203             Ronan   Doncillo   21  3.00      M    2019128203
# 12  2019128213          John Vic       Ilas   21  2.00      M    2019128213
# 13  2019128232             Aaron     Santos   21  3.14      M    2019128232
# 14  2019128253           Bridget      Plaza   20  2.00      F    2019128253
# 15  2019128272             Carlo   Sindayen   20  2.00      M    2019128272
# 16  2019128312              Karl  Tabajonda   21  1.00      M    2019128312
# 17  2019128314             Franz       Amog   21  3.00      M    2019128314
# 18  2019129789         Chlarizza     Torres   21  5.00      F    2019129789
# 19  2019130134       John Angelo    Algarne   20  4.20      M    2019130134
# 20  2019131291       Leira Marie    Teodoro   20  2.00      F    2019131291
# 21  2019131905             Keane     Tejada   20  1.00      M    2019131905
# 22  2019131907       Lester John   Quilaman   20  1.01      M    2019131907
# 23  2019132083            Angelo      Hizon   20  5.00      M    2019132083
# 24  2019132627          Abraham     Militar   20  2.00      M    2019132627
#
#     ustet_score  jhs_gwa  shs_gwa strand
# 0         85.00    90.00    95.00  HUMMS
# 1         80.00    91.00    94.00    ABM
# 2         88.00    89.68    91.36    ABM
# 3         85.00    92.00    89.00   STEM
# 4         90.00    87.00    85.00   STEM
# 5         75.00    76.00    77.00   STEM
# 6         85.00    85.00    85.00    ICT
# 7         69.42    80.08    96.69   STEM
# 8         90.00    91.00    94.00   STEM
# 9         76.00    75.00    75.00   STEM
# 10        97.00    94.17    93.24    ABM
# 11        96.00    84.00    90.00   STEM
# 12        86.00    84.00    91.00   STEM
# 13        92.00    87.50    88.90   STEM
# 14        91.00    91.00    91.00   STEM
# 15        85.00    86.00    92.00   PEST
# 16        90.00    91.00    92.00    ABM
# 17        89.00    90.00    90.00   STEM
# 18        95.00    96.00    97.00    GAS
# 19        69.00    88.88    77.77   STEM
# 20        89.50    90.00    87.00    ABM
# 21        90.00    90.00    90.00   STEM
# 22        79.00    89.00    99.00    MAD
# 23        87.00    91.42    93.00   STEM
# 24        88.00    90.00    91.00   STEM

# %%
query = """
    SELECT 
        *
    FROM 
        students_3csc 
    LEFT JOIN
        info2
    ON
        id = applicant_no
"""
left_join = pd.read_sql_query(query, conn)
left_join
# Out:
#             id         firstname familyname  age   gwa gender  applicant_no  \
# 0   2015081794             Allen    Marders   22  5.00      M    2015081794
# 1   2018107987       John Louise     Lagazo   21  1.69      M    2018107987
# 2   2018117965       Carl Joseph       Paez   21  2.00      M    2018117965
# 3   2019127901            Enrico      Oliva   20  3.00      M    2019127901
# 4   2019127972  Kerwin Dominique     Aquino   20  1.00      M    2019127972
# 5   2019128005          Dominick    Segundo   20  5.00      M    2019128005
# 6   2019128026  Lorenz Christian      Tadeo   21  3.00      M    2019128026
# 7   2019128089            Andrei    Benitez   20  4.20      M    2019128089
# 8   2019128145       Jasmine Joy        Lam   20  1.00      F    2019128145
# 9   2019128149             Rowel    Buluran   19  5.00      M    2019128149
# 10  2019128151             Anton     Bondoc   20  5.00      M    2019128151
# 11  2019128203             Ronan   Doncillo   21  3.00      M    2019128203
# 12  2019128213          John Vic       Ilas   21  2.00      M    2019128213
# 13  2019128232             Aaron     Santos   21  3.14      M    2019128232
# 14  2019128253           Bridget      Plaza   20  2.00      F    2019128253
# 15  2019128272             Carlo   Sindayen   20  2.00      M    2019128272
# 16  2019128312              Karl  Tabajonda   21  1.00      M    2019128312
# 17  2019128314             Franz       Amog   21  3.00      M    2019128314
# 18  2019129789         Chlarizza     Torres   21  5.00      F    2019129789
# 19  2019130134       John Angelo    Algarne   20  4.20      M    2019130134
# 20  2019131291       Leira Marie    Teodoro   20  2.00      F    2019131291
# 21  2019131905             Keane     Tejada   20  1.00      M    2019131905
# 22  2019131907       Lester John   Quilaman   20  1.01      M    2019131907
# 23  2019132083            Angelo      Hizon   20  5.00      M    2019132083
# 24  2019132627          Abraham     Militar   20  2.00      M    2019132627
#
#     ustet_score  jhs_gwa  shs_gwa strand
# 0         85.00    90.00    95.00  HUMMS
# 1         80.00    91.00    94.00    ABM
# 2         88.00    89.68    91.36    ABM
# 3         85.00    92.00    89.00   STEM
# 4         90.00    87.00    85.00   STEM
# 5         75.00    76.00    77.00   STEM
# 6         85.00    85.00    85.00    ICT
# 7         69.42    80.08    96.69   STEM
# 8         90.00    91.00    94.00   STEM
# 9         76.00    75.00    75.00   STEM
# 10        97.00    94.17    93.24    ABM
# 11        96.00    84.00    90.00   STEM
# 12        86.00    84.00    91.00   STEM
# 13        92.00    87.50    88.90   STEM
# 14        91.00    91.00    91.00   STEM
# 15        85.00    86.00    92.00   PEST
# 16        90.00    91.00    92.00    ABM
# 17        89.00    90.00    90.00   STEM
# 18        95.00    96.00    97.00    GAS
# 19        69.00    88.88    77.77   STEM
# 20        89.50    90.00    87.00    ABM
# 21        90.00    90.00    90.00   STEM
# 22        79.00    89.00    99.00    MAD
# 23        87.00    91.42    93.00   STEM
# 24        88.00    90.00    91.00   STEM

# %%
# using of pandas and engine to insert csv into the database
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:@Ngelo8998@localhost:3306/dw_3csc')

# %%
csv = pd.read_csv("3csc - csc_info2.csv")

# %%
csv.to_sql("info2", engine, index = False, if_exists = "replace")

# %%
query = """
    SELECT 
        id,
        gwa
    FROM 
        students_3csc 
    UNION
    SELECT 
        applicant_no,
        ustet_score
    FROM 
        info2
"""
union = pd.read_sql_query(query, conn)
union
# Out:
#             id    gwa
# 0   2015081794   5.00
# 1   2018107987   1.69
# 2   2018117965   2.00
# 3   2019127901   3.00
# 4   2019127972   1.00
# 5   2019128005   5.00
# 6   2019128026   3.00
# 7   2019128089   4.20
# 8   2019128145   1.00
# 9   2019128149   5.00
# 10  2019128151   5.00
# 11  2019128203   3.00
# 12  2019128213   2.00
# 13  2019128232   3.14
# 14  2019128253   2.00
# 15  2019128272   2.00
# 16  2019128312   1.00
# 17  2019128314   3.00
# 18  2019129789   5.00
# 19  2019130134   4.20
# 20  2019131291   2.00
# 21  2019131905   1.00
# 22  2019131907   1.01
# 23  2019132083   5.00
# 24  2019132627   2.00
# 25  2018107987  80.00
# 26  2019130134  69.00
# 27  2019132083  87.00
# 28  2019129789  95.00
# 29  2019132627  88.00
# 30  2019128089  69.42
# 31  2019131905  90.00
# 32  2019128151  97.00
# 33  2018117965  88.00
# 34  2019128312  90.00
# 35  2019128272  85.00
# 36  2019128232  92.00
# 37  2015081794  85.00
# 38  2019128253  91.00
# 39  2019127901  85.00
# 40  2019128145  90.00
# 41  2019128203  96.00
# 42  2019128149  76.00
# 43  2019128005  75.00
# 44  2019128314  89.00
# 45  2019127972  90.00
# 46  2019128026  85.00
# 47  2019131291  89.50
# 48  2019131907  79.00
# 49  2019128213  86.00

# %%
query = """
    SELECT 
        id,
        gwa
    FROM 
        students_3csc 
    UNION ALL
    SELECT 
        applicant_no,
        ustet_score
    FROM 
        info2
"""
union_all = pd.read_sql_query(query, conn)
union_all
# Out:
#             id    gwa
# 0   2015081794   5.00
# 1   2018107987   1.69
# 2   2018117965   2.00
# 3   2019127901   3.00
# 4   2019127972   1.00
# 5   2019128005   5.00
# 6   2019128026   3.00
# 7   2019128089   4.20
# 8   2019128145   1.00
# 9   2019128149   5.00
# 10  2019128151   5.00
# 11  2019128203   3.00
# 12  2019128213   2.00
# 13  2019128232   3.14
# 14  2019128253   2.00
# 15  2019128272   2.00
# 16  2019128312   1.00
# 17  2019128314   3.00
# 18  2019129789   5.00
# 19  2019130134   4.20
# 20  2019131291   2.00
# 21  2019131905   1.00
# 22  2019131907   1.01
# 23  2019132083   5.00
# 24  2019132627   2.00
# 25  2018107987  80.00
# 26  2019130134  69.00
# 27  2019132083  87.00
# 28  2019129789  95.00
# 29  2019132627  88.00
# 30  2019128089  69.42
# 31  2019131905  90.00
# 32  2019128151  97.00
# 33  2018117965  88.00
# 34  2019128312  90.00
# 35  2019128272  85.00
# 36  2019128232  92.00
# 37  2015081794  85.00
# 38  2019128253  91.00
# 39  2019127901  85.00
# 40  2019128145  90.00
# 41  2019128203  96.00
# 42  2019128149  76.00
# 43  2019128005  75.00
# 44  2019128314  89.00
# 45  2019127972  90.00
# 46  2019128026  85.00
# 47  2019131291  89.50
# 48  2019131907  79.00
# 49  2019128213  86.00

# %%
# Rollup
query = ('''
    SELECT 
    gender, gwa, age, AVG(gwa)
    FROM students_3csc
    GROUP BY gender, gwa, age WITH ROLLUP
''')
pd.read_sql(query, conn)
# Out:
#    gender   gwa   age  AVG(gwa)
# 0       F  1.00  20.0   1.00000
# 1       F  1.00   NaN   1.00000
# 2       F  2.00  20.0   2.00000
# 3       F  2.00   NaN   2.00000
# 4       F  5.00  21.0   5.00000
# 5       F  5.00   NaN   5.00000
# 6       F   NaN   NaN   2.50000
# 7       M  1.00  20.0   1.00000
# 8       M  1.00  21.0   1.00000
# 9       M  1.00   NaN   1.00000
# 10      M  1.01  20.0   1.01000
# 11      M  1.01   NaN   1.01000
# 12      M  1.69  21.0   1.69000
# 13      M  1.69   NaN   1.69000
# 14      M  2.00  20.0   2.00000
# 15      M  2.00  21.0   2.00000
# 16      M  2.00   NaN   2.00000
# 17      M  3.00  20.0   3.00000
# 18      M  3.00  21.0   3.00000
# 19      M  3.00   NaN   3.00000
# 20      M  3.14  21.0   3.14000
# 21      M  3.14   NaN   3.14000
# 22      M  4.20  20.0   4.20000
# 23      M  4.20   NaN   4.20000
# 24      M  5.00  19.0   5.00000
# 25      M  5.00  20.0   5.00000
# 26      M  5.00  22.0   5.00000
# 27      M  5.00   NaN   5.00000
# 28      M   NaN   NaN   2.96381
# 29   None   NaN   NaN   2.88960
